# %%
# %load_ext autoreload
# %autoreload 2
# %aimport -config.loader

# %%
# Imports and notebook bootstrap.
# Adjust for your stage. Use init_notebook(__name__) for the default pipeline config,
# or pass config_path= to a same-schema YAML file.

from config.loader import get_storage_path
from utils.notebooks_setup import ensure_storage_dirs, init_notebook

config, logger = init_notebook(__name__)
# config, logger = init_notebook(__name__, config_path="config/pipeline_config.yaml")

# Uncomment after configuring storage in YAML:
# ensure_storage_dirs()

# %% [markdown]
# ### Stage title (replace)
#
# One short paragraph: what this notebook does, what it reads, and what it writes.
#
# ```mermaid
# flowchart LR
#     In[Input] --> Step[Transform]
#     Step --> Out[Output]
# ```
#
# <details>
# <summary>Pipeline I/O</summary>
#
# > **Config:** link or path to the YAML keys this notebook uses.
# >
# > **Parameters:** list uppercase knobs defined below (`DATA_SOURCE`, etc.).
# >
# > **Input:** describe sources (tables, parquet glob, API).
# >
# > **Output:** files or tables produced, and where they live under `files/`.
#
# </details>

# %% [markdown]
# #### 1 — Configuration
#
# Set paths and feature flags. Prefer reading column lists and endpoints from `config` rather than duplicating them here.

# %%
DATA_SOURCE = "parquet"  # "parquet" | "db" | extend as needed

# Example: resolve storage roots from config
_tmp = get_storage_path("tmp")
_exports = get_storage_path("exports")

logger.info("DATA_SOURCE=%s", DATA_SOURCE)

# %% [markdown]
# #### 2 — Connectivity (optional)
#
# Database clients, cloud clients, or tunnels—only when `DATA_SOURCE` (or equivalent) requires them.

# %%
# db = DatabaseClient(config=config) if DATA_SOURCE == "db" else None
pass

# %% [markdown]
# #### 3 — Load / transform / save
#
# Split into additional `####` sections as the stage grows. Keep cells focused.

# %%
# Load inputs, apply library functions from src/, write outputs.
logger.info("Stage body: replace with real logic.")
